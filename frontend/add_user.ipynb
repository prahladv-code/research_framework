# %%
import json

users = [
    {'username': 'rishabhsingh',
     'password': 'rishabhsingh'},
    {'username': 'prahladvanvari',
      'password': 'mine2002'},
    {'username': 'darrentalati',
       'password': 'darrentalati'}
]

with open('./users.json', 'w') as f:
    json.dump(users, f, indent=2)

# %%
import pandas as pd
df = pd.read_parquet(r"C:\Users\Admin\Desktop\processed_parquets\20240708.parquet")
df
# Out:
#               date      time                  symbol      expiry right  \
# 0       2024-07-08  15:30:00   BANKEX2024070850700CE  2024-07-08    CE
# 1       2024-07-08  09:17:00   BANKEX2024070850700PE  2024-07-08    PE
# 2       2024-07-08  09:18:00   BANKEX2024070850700PE  2024-07-08    PE
# 3       2024-07-08  09:19:00   BANKEX2024070850700PE  2024-07-08    PE
# 4       2024-07-08  09:20:00   BANKEX2024070850700PE  2024-07-08    PE
# ...            ...       ...                     ...         ...   ...
# 405492  2024-07-08  21:50:00  SILVERM2024082198000CE  2024-08-21    CE
# 405493  2024-07-08  22:40:00  SILVERM2024082198000CE  2024-08-21    CE
# 405494  2024-07-08  23:02:00  SILVERM2024082198000CE  2024-08-21    CE
# 405495  2024-07-08  23:06:00  SILVERM2024082198000CE  2024-08-21    CE
# 405496  2024-07-08  23:22:00  SILVERM2024082198000CE  2024-08-21    CE
#
#          strike        o        h        l        c       v      oi  \
# ...
